# %% [markdown]
# # For loop

# %%
for i in range(5):
    print(i, "hej")

#Other lang
# for (int i = 0; i < 5; i++){
# statements
# }
# Out:
# 0 hej
# 1 hej
# 2 hej
# 3 hej
# 4 hej

# %%
for i in range(10):
    print(i, end = "t")
# Out:
# 0t1t2t3t4t5t6t7t8t9t

# %%
my_sum = 0

for i in range(10):
    my_sum += i

print(f" 0+1+2+3...+9 = {my_sum}")
# Out:
#  0+1+2+3...+9 = 45

# %% [markdown]
# # Loop through a list

# %%
cute_animals = ["rabbit", "guinea pig", "cat", "guppy"]

for animal in cute_animals:
    print(f"{animal} is cute")
# Out:
# rabbit is cute
# guinea pig is cute
# cat is cute
# guppy is cute

# %% [markdown]
# # Random module

# %%
import random
dice = random.randint(1, 6)
number_sixes = 0
number_rolls = 10

for i in range(number_rolls):
    dice = random.randint(1, 6)
    if dice == 6:
        number_sixes += 1

print(f"{number_sixes=}")
print(f"Proportion of sixes {number_sixes/number_rolls}")
# Out:
# number_sixes=2
# Proportion of sixes 0.2

# %% [markdown]
# ## Pasta
# nationella prov matte3c -ht14 upg 18

# %% [markdown]
# https://media.discordapp.net/attachments/1006123474269515786/1016255811598700594/unknown.png

# %%
import math

for year in range(10000):
    pasta_consumption = 0.791*math.exp(0.0526*year)
    if pasta_consumption >= 15:
        print(f"År {year+1960} är pasta konsumptionen är 15kg/person per år")
        break
# Out:
# År 2016 är pasta konsumptionen är 15kg/person per år

# %%
## b)

import matplotlib.pyplot as plt

# Creates empty list
pasta_per_year = []

# Loops 140 years - because 2100 - 1960
for year in range (140):
    pasta_consumption = 0.791*math.exp(0.0526*year)
    pasta_per_year.append(pasta_consumption)

plt.plot(range(1960, 2100), pasta_per_year)
plt.xlabel("År")
plt.ylabel("Pastakonsumption i kg")
plt.title("Pastakonsumption/kg per person per år från 1960")
print("SUPER mycket pasta")
# Out:
# SUPER mycket pasta

# %% [markdown]
# ```
# import math
#
# tid = 0
# pasta_konsumtion = 0
#
# while pasta_konsumtion < 15:
#     pasta_konsumtion = 0.791*math.e**(0.0526*tid)
#     print(tid+1960, pasta_konsumtion)
#     tid += 1
#
# ```

# %% [markdown]
# ## Nested Loops
# *loop in a loop
# want to print this :
# ```
# (1,1)(1,2)(1,3)
# (2,1)(2,2)(2,3)
# (3,1)(3,2)(3,3)
# ```

# %%
for row in range(1, 4):
    for col in range(1, 4):
        print(f"({row},{col})", end="")
    print() # newline
# Out:
# (1,1)(1,2)(1,3)
# (2,1)(2,2)(2,3)
# (3,1)(3,2)(3,3)
