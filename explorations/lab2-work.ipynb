# %% [markdown]
# ### 1. Import modules

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Load Data

# %%
df = pd.read_csv("datapoints.txt")
df.head()
# Out:
#    width(cm)  height(cm)  0_pichu-1_pikachu
# 0  21.959384   31.239567                  0
# 1  23.635916   36.468215                  1
# 2  17.714056   31.441704                  0
# 3  21.780200   33.213398                  1
# 4  25.206306   36.558816                  1

# %% [markdown]
# ### 3. Clean Data

# %%
# Drops NaN column
# df = df.dropna(axis=1) , fixed in txt file.

# Rename column
df = df.rename(columns={"0_pichu-1_pikachu": "Pichu0-Pika1", "width(cm)": "width", "height(cm)": "height"})
df.head()
# Out:
#        width     height  Pichu0-Pika1
# 0  21.959384  31.239567             0
# 1  23.635916  36.468215             1
# 2  17.714056  31.441704             0
# 3  21.780200  33.213398             1
# 4  25.206306  36.558816             1

# %%
# Check data types and info
df.info(), df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   width         150 non-null    float64
#  1   height        150 non-null    float64
#  2   Pichu0-Pika1  150 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 3.6 KB
# (None,
#              width      height  Pichu0-Pika1
#  count  150.000000  150.000000    150.000000
#  mean    22.062142   33.598281      0.500000
#  std      2.497307    2.159651      0.501675
#  min     16.866105   28.888134      0.000000
#  25%     19.921975   32.005462      0.000000
#  50%     22.040754   33.315877      0.500000
#  75%     24.316733   35.320895      1.000000
#  max     27.194384   40.147170      1.000000)

# %% [markdown]
# ## Visualize the Data

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(df["width"], 
                     df["height"], 
                     c=df["Pichu0-Pika1"])

# Customize the plot
ax.set(title="Pichu and Pikachu",
       xlabel="Width",
       ylabel="Height")
ax.legend(*scatter.legend_elements(), title="Pichu0-Pika1");

# %% [markdown]
# ## Prepare Data for Training
