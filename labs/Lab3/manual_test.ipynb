# %% [markdown]
# ## UML Diagram

# %% [markdown]
# ![image info](GeometryClass.png)

# %% [markdown]
# ## Manual Testing

# %%
from math import pi
from math import sqrt
from GeometryClass import Geometry, Rectangle, Circle

# %%
cirkel1 = Circle(x=0,y=0, radius=1) # enhetscirkel
cirkel2 = Circle(x=1,y=1, radius=1)
print(cirkel1)
print(cirkel2)

print(f"Whether the two circles are equal: {cirkel1==cirkel2}") # True

print(f"The radius of cirkel1 is: {cirkel1.radius}")
print(f"The radius of cirkel2 is: {cirkel2.radius}")

print(f"The area of cirkel1 is: {cirkel1.area():.2f}")
print(f"The area of cirkel2 is: {cirkel2.area():.2f}")

print(f"The perimeter of cirkel1 is: {cirkel1.perimeter():.2f}")
print(f"The perimeter of cirkel2 is: {cirkel2.perimeter():.2f}")

print(f"Whether (0.5, 0.5) is in cirkel1: {cirkel1.is_inside(0.5, 0.5)}.")
cirkel1.plot_circle(0.5, 0.5)


print(f"Whether (0.5, 0.5) is in cirkel2: {cirkel2.is_inside(0.5, 0.5)}.")
cirkel2.plot_circle(0.5, 0.5)

print(f"Whether (1.5, 1.5) is in cirkel1: {cirkel1.is_inside(1.5, 1.5)}.")
cirkel1.plot_circle(1.5, 1.5)

print(f"Whether (1.5, 1.5) is in cirkel2: {cirkel2.is_inside(1.5, 1.5)}.")
cirkel2.plot_circle(1.5, 1.5)

print(f"Whether (3, 3) is in cirkel1: {cirkel1.is_inside(3, 3)}.")
cirkel1.plot_circle(3, 3)

print(f"Whether (3, 3) is in cirkel2: {cirkel2.is_inside(3, 3)}.")
cirkel2.plot_circle(3, 3)
# Out:
# Circle with center point: (0, 0), Radius: 1
# Circle with center point: (1, 1), Radius: 1
# Whether the two circles are equal: True
# The radius of cirkel1 is: 1
# The radius of cirkel2 is: 1
# The area of cirkel1 is: 3.14
# The area of cirkel2 is: 3.14
# The perimeter of cirkel1 is: 6.28
# The perimeter of cirkel2 is: 6.28
# Whether (0.5, 0.5) is in cirkel1: True.
# Whether (0.5, 0.5) is in cirkel2: True.
# Whether (1.5, 1.5) is in cirkel1: False.
# Whether (1.5, 1.5) is in cirkel2: True.
# Whether (3, 3) is in cirkel1: False.
# Whether (3, 3) is in cirkel2: False.
