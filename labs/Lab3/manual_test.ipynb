# %% [markdown]
# ## UML Diagram

# %% [markdown]
# ![image info](GeometryClass.png)

# %% [markdown]
# ## Manual Testing

# %%
from math import pi
from math import sqrt
from GeometryClass import Geometry, Rectangle, Circle

# %% [markdown]
# ## Rectangle

# %%
rectangle = Rectangle(x=0,y=0,side1=2, side2=2)
print(rectangle)
print(f"-"*50)

print(f"Rectangle Area: {rectangle.area()}")
print(f"Rectangle Perimeter: {rectangle.perimeter()}")
print(f"-"*50)

rectangle1 = Rectangle(x=0,y=0,side1=2, side2=1)
rectangle2 = Rectangle(x=0,y=0,side1=1, side2=2)
print(f"Shape 1: {rectangle1}")
print(f"Shape 2: {rectangle2}")
print(f"Is shape 1 equal to shape 2?: {rectangle1 == rectangle2}")
print(f"-"*50)
# Out:
# Rectangle X and Y midpoint: (0, 0). Horizontal and vertical lenght: (2, 2).
# --------------------------------------------------
# Rectangle Area: 4
# Rectangle Perimeter: 8
# --------------------------------------------------
# Shape 1: Rectangle X and Y midpoint: (0, 0). Horizontal and vertical lenght: (2, 1).
# Shape 2: Rectangle X and Y midpoint: (0, 0). Horizontal and vertical lenght: (1, 2).
# Is shape 1 equal to shape 2?: True
# --------------------------------------------------

# %% [markdown]
# ### Rectangle Plots

# %%
rectangle = Rectangle(x=0,y=0,side1=2, side2=2)
print(f"-"*25 + "PLOTS" + "-"*25)
print(f"Shape with equal sides(2, 2). Should look like an square")
rectangle.plot_rectangle()
print(f"-"*50)

rectangle = Rectangle(x=0,y=0,side1=2, side2=1)
print(f"Shape with uneven sides(2, 1). Should look like an rectangle")
rectangle.plot_rectangle()
print(f"-"*50)


rectangle = Rectangle(x=0,y=0,side1=2, side2=1)
print(f"Rectangle\nCheck if point(0.25, 0.25) is inside: {rectangle.is_inside(0.25, 0.25)}") 
rectangle.plot_rectangle(0.25, 0.25)

rectangle = Rectangle(x=0,y=0,side1=2, side2=1)
print(f"Rectangle\nCheck if point(3, 3) is inside: {rectangle.is_inside(3, 3)}") # False
rectangle.plot_rectangle(3, 3)
# Out:
# -------------------------PLOTS-------------------------
# Shape with equal sides(2, 2). Should look like an square
# --------------------------------------------------
# Shape with uneven sides(2, 1). Should look like an rectangle
# --------------------------------------------------
# Rectangle
# Check if point(0.25, 0.25) is inside: True
# Rectangle
# Check if point(3, 3) is inside: False

# %% [markdown]
# ### Rectangle Move

# %%
rectangle1 = Rectangle(x=1,y=1, side1=2, side2=1) 
print(rectangle1)

print(f"Move the rectangle by (5,5)\n\nNew position:")
rectangle1.move(5,5)
print(rectangle1)
# Out:
# Rectangle X and Y midpoint: (1, 1). Horizontal and vertical lenght: (2, 1).
# Move the rectangle by (5,5)
#
# New position:
# Rectangle X and Y midpoint: (6, 6). Horizontal and vertical lenght: (2, 1).

# %% [markdown]
# ### Rectangle Error

# %%
try:
    rectangle1.move("TRE",5)
except TypeError as err:
    print(err)
# Out:
# Only integer or float allowed, <class 'str'> is invalid.

# %% [markdown]
# ## Circle

# %%
circle1 = Circle(x=0,y=0, radius=1) 
circle2 = Circle(x=1,y=1, radius=1)
print(circle1)
print(circle2)
print(f"-"*50)

print(f"Are the circles equal?: {circle1==circle2}")
print(f"Is circle 1 equal to rectangle?: {circle1==rectangle}") # False
print(f"Circle 1 radius: {circle1.radius}")
print(f"Circle 2 radius: {circle2.radius}")

print(f"Cirkel 1 area: {circle1.area():.2f}")
print(f"Cirkel 2 area: {circle2.area():.2f}")

print(f"Circle 1 perimeter: {circle1.perimeter():.2f}")
print(f"Circle 2 perimeter: {circle2.perimeter():.2f}")
print(f"-"*50)
# Out:
# Circle midpoint X and Y: (0, 0)
# Radius: 1
# Circle midpoint X and Y: (1, 1)
# Radius: 1
# --------------------------------------------------
# Are the circles equal?: True
# Is circle 1 equal to rectangle?: False
# Circle 1 radius: 1
# Circle 2 radius: 1
# Cirkel 1 area: 3.14
# Cirkel 2 area: 3.14
# Circle 1 perimeter: 6.28
# Circle 2 perimeter: 6.28
# --------------------------------------------------

# %% [markdown]
# ### Circle Plots

# %%
print(f"-"*25 + "PLOTS" + "-"*25)
print(f"Circle 1")
circle1.plot_circle()
print(f"-"*50)


print(f"Circle 2\nCheck if point(0.5, 0.5) is inside: {circle2.is_inside(0.5, 0.5)}.")
circle2.plot_circle(0.5, 0.5)
print(f"-"*50)

print(f"Circle 1\nCheck if point(1.5, 1.5) is inside: {circle1.is_inside(1.5, 1.5)}.")
circle1.plot_circle(1.5, 1.5)
print(f"-"*50)

print(f"Circle 2\nCheck if point(1.5, 1.5) is inside: {circle2.is_inside(1.5, 1.5)}.")
circle2.plot_circle(1.5, 1.5)
print(f"-"*50)

print(f"Circle 1\nCheck if point(2, 2) is inside: {circle1.is_inside(3, 3)}.")
circle1.plot_circle(2, 2)
print(f"-"*50)

print(f"Circle 2\nCheck if point(2, 2) is inside: {circle2.is_inside(3, 3)}.")
circle2.plot_circle(2, 2)
print(f"-"*50)
# Out:
# -------------------------PLOTS-------------------------
# Circle 1
# --------------------------------------------------
# Circle 2
# Check if point(0.5, 0.5) is inside: True.
# --------------------------------------------------
# Circle 1
# Check if point(1.5, 1.5) is inside: False.
# --------------------------------------------------
# Circle 2
# Check if point(1.5, 1.5) is inside: True.
# --------------------------------------------------
# Circle 1
# Check if point(2, 2) is inside: False.
# --------------------------------------------------
# Circle 2
# Check if point(2, 2) is inside: False.
# --------------------------------------------------

# %% [markdown]
# ### Circle Move

# %%
circle1 = Circle(x=1,y=1, radius=2) 
print(circle1)

circle1.move(5,5)
print(circle1)
# Out:
# Circle midpoint X and Y: (1, 1)
# Radius: 2
# Circle midpoint X and Y: (6, 6)
# Radius: 2

# %% [markdown]
# ### Circle Error

# %%
try:
    circle1.move("TRE",5)
except TypeError as err:
    print(err)
# Out:
# Only integer or float allowed, <class 'str'> is invalid.
